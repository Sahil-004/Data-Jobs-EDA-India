# %% [markdown]
# # What is the most optimal skill to learn for Data Analysts?
#
# #### Methodology
#
# 1. Continue from last notebook to find percent of postings with skill
# 2. Visualize median salary vs percent skill demand
# 3. (Optional) Determine if certain technologies are more prevalent

# %% [markdown]
# ## Import Libraries and Data

# %%
# Importing Libraries
import ast
import pandas as pd
import seaborn as sns
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %% [markdown]
# ## Clean Data
#
# Filters the original dataset to only get rows where the job title is 'Data Analyst' and the country is 'United States', to create a new DataFrame `df_DA_US`. Drop NaN values from the 'salary_year_avg' column. Then it uses the `explode` method on the `job_skills` column to create a new row in a new DataFrame (`df_DA_US_exploded`) for each skill associated with a job. Finally, it displays the first 5 entries of the `salary_year_avg` and `job_skills` columns.

# %%
df_DA_Ind = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'India')].copy()

# Drop NaN values from the 'salary_year_avg' column for accurate visualization
df_DA_Ind = df_DA_Ind.dropna(subset=['salary_year_avg'])

df_DA_Ind_exploded = df_DA_Ind.explode('job_skills')

df_DA_Ind_exploded[['salary_year_avg', 'job_skills']].head(5)
# Out:
#        salary_year_avg job_skills
# 11412          50400.0     python
# 11412          50400.0        sql
# 11412          50400.0        aws
# 11412          50400.0      azure
# 11412          50400.0      excel

# %% [markdown]
# ## Calculate Percent of Job Postings that Have Skills
# Group the data by job skills and calculates the count and median salary for each skill, sorting the results in descending order by count. It then renames the columns. Calculates the percentage that each skill count represents out of the total number of Data Analyst jobs. Finally, filter out any skills that don't have any jobs associated with them.

# %%
# using df_DA find the count of skills and also the median salary for each skill
df_DA_skills = df_DA_Ind_exploded.groupby('job_skills')['salary_year_avg'].agg(['count', 'median']).sort_values(by='count', ascending=False)

df_DA_skills = df_DA_skills.rename(columns={'count': 'skill_count', 'median': 'median_salary'})

DA_job_count = len(df_DA_Ind)  # Find count of Data Analyst jobs in India with salary info

df_DA_skills['skill_percent'] = df_DA_skills['skill_count'] / DA_job_count * 100

df_DA_skills = df_DA_skills[df_DA_skills['skill_count'] > 0]

df_DA_skills
# Out:
#             skill_count  median_salary  skill_percent
# job_skills
# sql                  46        96050.0      48.936170
# excel                39        98500.0      41.489362
# python               36        96050.0      38.297872
# tableau              20       108087.5      21.276596
# r                    18        79200.0      19.148936
# ...                 ...            ...            ...
# unify                 1        79200.0       1.063830
# unreal                1       105650.0       1.063830
# visio                 1       119250.0       1.063830
# windows               1        79200.0       1.063830
# zoom                  1       104500.0       1.063830
#
# [83 rows x 3 columns]

# %% [markdown]
# ## Median Salary vs Percent Skill Demand
# Filters for Data Analyst skills that exceed a certain percentage (`skill_limit`).

# %%
skill_limit = 5

df_DA_skills_high_demand = df_DA_skills[df_DA_skills['skill_percent'] > skill_limit]

# %% [markdown]
# Create a scatter plot to visualize the relationship between the percentage of Data Analyst jobs that require specific skills and the median salary for those skills.

# %%
from adjustText import adjust_text
import matplotlib.pyplot as plt

# 1. Increase figure size to give labels enough room
plt.figure(figsize=(10, 6))

# 2. Scatter plot
plt.scatter(df_DA_skills_high_demand['skill_percent'], df_DA_skills_high_demand['median_salary'])
plt.xlabel('Percent of Data Analyst Jobs')
plt.ylabel('Median Salary ($USD)')
plt.title('Most Optimal Skills for Data Analysts in India')

# 3. Format Y-axis
ax = plt.gca()
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f'${int(y/1000)}K'))

# 4. Collect text elements
texts = []
for i, txt in enumerate(df_DA_skills_high_demand.index):
    texts.append(
        plt.text(
            df_DA_skills_high_demand['skill_percent'].iloc[i], 
            df_DA_skills_high_demand['median_salary'].iloc[i], 
            txt, 
            fontsize=10
        )
    )

# 5. Pass x and y coordinates into adjust_text to force repelling from data points
adjust_text(
    texts, 
    x=df_DA_skills_high_demand['skill_percent'], 
    y=df_DA_skills_high_demand['median_salary'],
    arrowprops=dict(arrowstyle='->', color='gray', lw=0.8),
    expand_text=(1.2, 1.4)  # Gives extra buffer around text boxes
)

plt.tight_layout()
plt.show()
# Out:
# Looks like you are using a tranform that doesn't support FancyArrowPatch, using ax.annotate instead. The arrows might strike through texts. Increasing shrinkA in arrowprops might help.

# %% [markdown]
# ##  Coloring by Technology
# We're going to add color labels based on technology.
#
# Removes duplicate entries and any rows with missing values. Then, it combines all dictionary entries into a single dictionary, summing values for keys that repeat across entries. To ensure each key's values are unique, it converts the values to a set and then back to a list. The final result is a dictionary where each key represents a skill and each value is a list of unique attributes associated with that skill.

# %%
df_technology = df['job_type_skills'].copy()

# remove duplicates
df_technology = df_technology.drop_duplicates()

# remove NaN values
df_technology = df_technology.dropna()

# combine all dictionaries into one
technology_dict = {}
for row in df_technology:
    row_dict = ast.literal_eval(row)  # convert string to dictionary
    for key, value in row_dict.items():
        if key in technology_dict:  # if key already exists in technology_dict, add value to existing value
            technology_dict[key] += value
        else:                       # if key does not exist in technology_dict, add key and value
            technology_dict[key] = value

# remove duplicates by converting values to set then back to list
for key, value in technology_dict.items():
    technology_dict[key] = list(set(value))

technology_dict
# Out:
# {'analyst_tools': ['nuix',
#   'word',
#   'alteryx',
#   'spreadsheet',
#   'dax',
#   'msaccess',
#   'power bi',
#   'microstrategy',
#   'ms access',
#   'powerbi',
#   'cognos',
#   'esquisse',
#   'splunk',
#   'qlik',
#   'sap',
#   'sas',
#   'sheets',
#   'datarobot',
#   'outlook',
#   'spss',
#   'visio',
#   'tableau',
#   'powerpoint',
#   'ssrs',
#   'sharepoint',
#   'looker',
#   'ssis',
#   'excel'],
#  'programming': ['java',
#   'c',
#   'dart',
#   'c++',
#   'ruby',
#   'vb.net',
#   't-sql',
#   'mongo',
#   'haskell',
#   'fortran',
#   'c#',
#   'typescript',
#   'elixir',
#   'swift',
#   'clojure',
#   'vba',
#   'sql',
#   'lisp',
#   'solidity',
#   'perl',
#   'sas',
#   'php',
#   'mongodb',
#   'r',
#   'groovy',
#   'cobol',
#   'no-sql',
#   'lua',
#   'powershell',
#   'matlab',
#   'bash',
#   'rust',
#   'erlang',
#   'visualbasic',
#   'html',
#   'julia',
#   'ocaml',
#   'nosql',
#   'javascript',
#   'css',
#   'crystal',
#   'f#',
#   'delphi',
#   'shell',
#   'apl',
#   'visual basic',
#   'assembly',
#   'kotlin',
#   'pascal',
#   'objective-c',
#   'python',
#   'go',
#   'golang',
#   'scala',
#   'sass'],
#  'cloud': ['azure',
#   'aurora',
#   'bigquery',
#   'digitalocean',
#   'databricks',
#   'gcp',
#   'vmware',
#   'openstack',
#   'colocation',
#   'heroku',
#   'linode',
#   'redshift',
#   'aws',
#   'watson',
#   'snowflake',
#   'ibm cloud',
#   'firebase',
#   'ovh',
#   'oracle'],
#  'libraries': ['gdpr',
#   'ggplot2',
#   'tidyverse',
#   'qt',
#   'opencv',
#   'ionic',
#   'jupyter',
#   'tidyr',
#   'hugging face',
#   'selenium',
#   'dplyr',
#   'shogun',
#   'spring',
#   'cordova',
#   'gtx',
#   'kafka',
#   'graphql',
#   'tensorflow',
#   'numpy',
#   'plotly',
#   'theano',
#   'react',
#   'hadoop',
#   'seaborn',
#   'electron',
#   'mlpack',
#   'pandas',
#   'nltk',
#   'flutter',
#   'mlr',
#   'pyspark',
#   'rshiny',
#   'matplotlib',
#   'keras',
#   'huggingface',
#   'scikit-learn',
#   'mxnet',
#   'pytorch',
#   'chainer',
#   'capacitor',
#   'spark',
#   'xamarin',
#   'dlib',
#   'airflow'],
#  'other': ['npm',
#   'bitbucket',
#   'terraform',
#   'svn',
#   'homebrew',
#   'chef',
#   'flow',
#   'github',
#   'atlassian',
#   'terminal',
#   'docker',
#   'git',
#   'gitlab',
#   'jenkins',
#   'kubernetes',
#   'puppet',
#   'ansible',
#   'yarn',
#   'codecommit',
#   'unity',
#   'unreal',
#   'pulumi'],
#  'databases': ['couchbase',
#   'neo4j',
#   'cassandra',
#   'postgresql',
#   'mariadb',
#   'mongodb',
#   'sqlite',
#   'sql server',
#   'db2',
#   'firestore',
#   'sqlserver',
#   'mysql',
#   'redis',
#   'dynamodb',
#   'couchdb',
#   'elasticsearch',
#   'firebase'],
#  'os': ['linux',
#   'arch',
#   'unix',
#   'suse',
#   'redhat',
#   'macos',
#   'ubuntu',
#   'kali',
#   'centos',
#   'windows',
#   'debian',
#   'wsl',
#   'fedora'],
#  'async': ['workfront',
#   'notion',
#   'wimi',
#   'microsoft lists',
#   'clickup',
#   'confluence',
#   'smartsheet',
#   'jira',
#   'wrike',
#   'monday.com',
#   'planner',
#   'asana',
#   'airtable',
#   'dingtalk',
#   'trello'],
#  'webframeworks': ['ruby on rails',
#   'asp.netcore',
#   'deno',
#   'ember.js',
#   'asp.net',
#   'fastapi',
#   'blazor',
#   'phoenix',
#   'fastify',
#   'django',
#   'express',
#   'react.js',
#   'play framework',
#   'node',
#   'gatsby',
#   'asp.net core',
#   'flask',
#   'symfony',
#   'angular.js',
#   'nuxt.js',
#   'drupal',
#   'vue',
#   'node.js',
#   'svelte',
#   'vue.js',
#   'next.js',
#   'angular',
#   'laravel',
#   'rubyon rails',
#   'ruby',
#   'jquery'],
#  'sync': ['unify',
#   'rocketchat',
#   'symphony',
#   'zoom',
#   'microsoft teams',
#   'slack',
#   'webex',
#   'ringcentral',
#   'wire',
#   'google chat',
#   'twilio',
#   'mattermost']}

# %% [markdown]
# This code converts a dictionary into a pandas DataFrame, then explodes the 'skills' column, creating multiple rows for each 'technology' entry if it contains multiple skills.

# %%
# turn dictionary into dataframe
df_technology = pd.DataFrame(list(technology_dict.items()), columns=['technology', 'skills'])

df_technology = df_technology.explode('skills')

df_technology
# Out:
#        technology       skills
# 0   analyst_tools         nuix
# 0   analyst_tools         word
# 0   analyst_tools      alteryx
# 0   analyst_tools  spreadsheet
# 0   analyst_tools          dax
# ..            ...          ...
# 9            sync  ringcentral
# 9            sync         wire
# 9            sync  google chat
# 9            sync       twilio
# 9            sync   mattermost
#
# [256 rows x 2 columns]

# %% [markdown]
# Merges two DataFrames, `df_DA_skills` and `df_technology`, based on the columns 'job_skills' and 'skills' respectively, creating a new DataFrame `df_DA_skills_tech`.

# %%
# merge df_DA_skills and df_technology
df_DA_skills_tech = df_DA_skills.merge(df_technology, left_on='job_skills', right_on='skills')

df_DA_skills_tech
# Out:
#     skill_count  median_salary  skill_percent     technology   skills
# 0            46        96050.0      48.936170    programming      sql
# 1            39        98500.0      41.489362  analyst_tools    excel
# 2            36        96050.0      38.297872    programming   python
# 3            20       108087.5      21.276596  analyst_tools  tableau
# 4            18        79200.0      19.148936    programming        r
# ..          ...            ...            ...            ...      ...
# 80            1        79200.0       1.063830           sync    unify
# 81            1       105650.0       1.063830          other   unreal
# 82            1       119250.0       1.063830  analyst_tools    visio
# 83            1        79200.0       1.063830             os  windows
# 84            1       104500.0       1.063830           sync     zoom
#
# [85 rows x 5 columns]

# %% [markdown]
# Filters `df_DA_skills_tech` to select rows where the 'percent' column exceeds a specified threshold, storing the result in `df_DA_skills_tech_high_demand`.

# %%
df_DA_skills_tech_high_demand = df_DA_skills_tech[df_DA_skills_tech['skill_percent'] > skill_limit]

# %% [markdown]
# Plot the results in a scatter plot, coloring the points based on the 'technology' column.

# %%
from matplotlib.ticker import PercentFormatter

# 1. Ensure the skill names are set as the DataFrame index
# (Change 'skills' to 'job_skills' below if your column is named 'job_skills')
if 'skills' in df_DA_skills_tech_high_demand.columns:
    df_DA_skills_tech_high_demand = df_DA_skills_tech_high_demand.set_index('skills')
elif 'job_skills' in df_DA_skills_tech_high_demand.columns:
    df_DA_skills_tech_high_demand = df_DA_skills_tech_high_demand.set_index('job_skills')

# 2. Set theme and figure size
sns.set_theme(style='ticks')
plt.figure(figsize=(11, 7))

# 3. Scatter plot
sns.scatterplot(
    data=df_DA_skills_tech_high_demand,
    x='skill_percent',
    y='median_salary',
    hue='technology',
    palette='tab10',
    s=60
)
sns.despine()

# 4. Collect text labels directly from the updated index
texts = []
for i, txt in enumerate(df_DA_skills_tech_high_demand.index):
    texts.append(
        plt.text(
            df_DA_skills_tech_high_demand['skill_percent'].iloc[i], 
            df_DA_skills_tech_high_demand['median_salary'].iloc[i], 
            txt,
            fontsize=9
        )
    )

# 5. Repel overlapping text labels
adjust_text(
    texts,
    x=df_DA_skills_tech_high_demand['skill_percent'],
    y=df_DA_skills_tech_high_demand['median_salary'],
    arrowprops=dict(arrowstyle='->', color='gray', lw=0.8),
    expand_text=(1.2, 1.4)
)

# 6. Set labels and format axes
plt.xlabel('Percent of Data Analyst Jobs', fontsize=11)
plt.ylabel('Median Yearly Salary', fontsize=11)
plt.title('Most Optimal Skills for Data Analysts in India', fontsize=14, pad=12)
plt.legend(title='Technology', bbox_to_anchor=(1.05, 1), loc='upper left')

ax = plt.gca()
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f'${int(y/1000)}K'))
ax.xaxis.set_major_formatter(PercentFormatter(decimals=0))

plt.tight_layout()
plt.show()
